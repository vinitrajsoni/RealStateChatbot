# %%
import pandas as pd

# Load all CSV files from the "Data" folder
project = pd.read_csv("Data/project.csv")
address = pd.read_csv("Data/ProjectAddress.csv")
config = pd.read_csv("Data/ProjectConfiguration.csv")
variant = pd.read_csv("Data/ProjectConfigurationVariant.csv")

# %%
project.columns
# Out:
# Index(['id', 'projectType', 'projectName', 'projectCategory', 'slug', 'slugId',
#        'status', 'projectAge', 'reraId', 'countryId', 'stateId', 'cityId',
#        'localityId', 'subLocalityId', 'projectSummary', 'possessionDate'],
#       dtype='object')

# %%
address.columns
# Out:
# Index(['id', 'projectId', 'landmark', 'fullAddress', 'pincode'], dtype='object')

# %%
config.columns
# Out:
# Index(['id', 'projectId', 'propertyCategory', 'type', 'customBHK'], dtype='object')

# %%
variant.columns
# Out:
# Index(['id', 'configurationId', 'bathrooms', 'privateBathrooms',
#        'publicBathrooms', 'balcony', 'furnishedType', 'furnishingType', 'lift',
#        'ageOfProperty', 'parkingType', 'listingType', 'floorPlanImage',
#        'carpetArea', 'price', 'propertyImages', 'maintenanceCharges',
#        'aboutProperty', 'createdAt', 'updatedAt'],
#       dtype='object')

# %%
project = project.rename(columns={'id': 'projectId'})
config = config.rename(columns={'id': 'configurationId'})
variant = variant.rename(columns={'id': 'variantId'})

# %%
merged_1 = pd.merge(project, address, on='projectId', how='left')
merged_1.columns
# Out:
# Index(['projectId', 'projectType', 'projectName', 'projectCategory', 'slug',
#        'slugId', 'status', 'projectAge', 'reraId', 'countryId', 'stateId',
#        'cityId', 'localityId', 'subLocalityId', 'projectSummary',
#        'possessionDate', 'id', 'landmark', 'fullAddress', 'pincode'],
#       dtype='object')

# %%
merged_2 = pd.merge(merged_1, config, on='projectId', how='left')
merged_2.columns
# Out:
# Index(['projectId', 'projectType', 'projectName', 'projectCategory', 'slug',
#        'slugId', 'status', 'projectAge', 'reraId', 'countryId', 'stateId',
#        'cityId', 'localityId', 'subLocalityId', 'projectSummary',
#        'possessionDate', 'id', 'landmark', 'fullAddress', 'pincode',
#        'configurationId', 'propertyCategory', 'type', 'customBHK'],
#       dtype='object')

# %%
final = pd.merge(merged_2, variant, on='configurationId', how='left')
final.columns
# Out:
# Index(['projectId', 'projectType', 'projectName', 'projectCategory', 'slug',
#        'slugId', 'status', 'projectAge', 'reraId', 'countryId', 'stateId',
#        'cityId', 'localityId', 'subLocalityId', 'projectSummary',
#        'possessionDate', 'id', 'landmark', 'fullAddress', 'pincode',
#        'configurationId', 'propertyCategory', 'type', 'customBHK', 'variantId',
#        'bathrooms', 'privateBathrooms', 'publicBathrooms', 'balcony',
#        'furnishedType', 'furnishingType', 'lift', 'ageOfProperty',
#        'parkingType', 'listingType', 'floorPlanImage', 'carpetArea', 'price',
#        'propertyImages', 'maintenanceCharges', 'aboutProperty', 'createdAt',
#        'updatedAt'],
#       dtype='object')

# %%
final.shape
# Out:
# (83, 43)

# %%
final.sample(2)
# Out:
#                     projectId  projectType projectName projectCategory  \
# 45  cmfdmdqmq0008vc90svu2sfto  RESIDENTIAL    Antriksh      STANDALONE
# 42  cmfcg9ren0001vc209rw25eve  RESIDENTIAL       Glory      STANDALONE
#
#                                            slug  slugId              status  \
# 45  luxury-antriksh-somwarpeth-camp-pune-997560     NaN  UNDER_CONSTRUCTION
# 42  luxury-glory-katewasti-punawale-pune-268353     NaN  UNDER_CONSTRUCTION
#
#     projectAge                           reraId                  countryId  \
# 45         NaN  ["P52100019454","P52100047488"]  cmf3zcoe80000vcf8sd4qfpwd
# 42         NaN           ["[\"P52100077028\"]"]  cmf3zcoe80000vcf8sd4qfpwd
#
#     ... parkingType listingType  \
# 45  ...         NaN        Sell
# 42  ...         NaN        Sell
#
#                                        floorPlanImage carpetArea     price  \
# 45                                                NaN      900.0  18900000
# ...

# %%
final.to_csv("Data/Merged_Project_Data.csv", index=False)

# %%
import pandas as pd

df = pd.read_csv("Data/Merged_Project_Data.csv")
df.isnull().sum()
# Out:
# projectId              0
# projectType            0
# projectName            0
# projectCategory        0
# slug                   0
# slugId                83
# status                 0
# projectAge            72
# reraId                 0
# countryId              0
# stateId                0
# cityId                 0
# localityId             0
# subLocalityId          0
# projectSummary        65
# possessionDate        66
# id                     0
# landmark               0
# fullAddress            0
# pincode                0
# configurationId        0
# propertyCategory       0
# type                   0
# customBHK             14
# variantId              0
# bathrooms              0
# privateBathrooms      80
# publicBathrooms       80
# balcony                3
# furnishedType          0
# furnishingType         0
# lift                   0
# ageOfProperty         83
# parkingType           83
# listingType            0
# floorPlanImage         2
# carpetArea             0
# ...

# %%
import pandas as pd

# Step 1: Load the CSV file
df = pd.read_csv("Data\Merged_Project_Data.csv")

# Step 2: Fill all empty or NaN cells with "Unknown"
df_filled = df.fillna("Unknown")

# Step 3: (Optional) Save the cleaned version
df_filled.to_csv("Cleaned_Project_Data.csv", index=False)

print("✅ All empty cells have been replaced with 'Unknown' and saved as Cleaned_Project_Data.csv")
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\M'
# <>:4: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\user\AppData\Local\Temp\ipykernel_8632\1844431237.py:4: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_csv("Data\Merged_Project_Data.csv")
# ✅ All empty cells have been replaced with 'Unknown' and saved as Cleaned_Project_Data.csv

# %%
import pandas as pd
df = pd.read_csv('Data\Cleaned_Project_Data.csv')
df.columns
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\C'
# <>:2: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\user\AppData\Local\Temp\ipykernel_14180\1214916813.py:2: SyntaxWarning: invalid escape sequence '\C'
#   df = pd.read_csv('Data\Cleaned_Project_Data.csv')
# Index(['projectId', 'projectType', 'projectName', 'projectCategory', 'slug',
#        'slugId', 'status', 'projectAge', 'reraId', 'countryId', 'stateId',
#        'cityId', 'localityId', 'subLocalityId', 'projectSummary',
#        'possessionDate', 'id', 'landmark', 'fullAddress', 'pincode',
#        'configurationId', 'propertyCategory', 'type', 'customBHK', 'variantId',
#        'bathrooms', 'privateBathrooms', 'publicBathrooms', 'balcony',
#        'furnishedType', 'furnishingType', 'lift', 'ageOfProperty',
#        'parkingType', 'listingType', 'floorPlanImage', 'carpetArea', 'price',
#        'propertyImages', 'maintenanceCharges', 'aboutProperty', 'createdAt',
#        'updatedAt'],
#       dtype='object')

# %%
df_clean = df[[
    "projectName", "cityId", "localityId", "type", 
    "price", "status", "slug", "projectSummary", "propertyImages", "fullAddress"
]].copy()

# %%
df_clean.head()
# Out:
#   projectName                     cityId                 localityId  type  \
# 0     Ashwini  cmf6nu3ru000gvcxspxarll3v  cmf6pksk30035vcxs7r2mo3iq  1BHK
# 1     Ashwini  cmf6nu3ru000gvcxspxarll3v  cmf6pksk30035vcxs7r2mo3iq  2BHK
# 2  Pristine02  cmf6nu3ru000gvcxspxarll3v  cmf6pk0cn0033vcxshxbf5hdh  2BHK
# 3  Pristine02  cmf6nu3ru000gvcxspxarll3v  cmf6pk0cn0033vcxshxbf5hdh  2BHK
# 4   Gurukripa  cmf50r5a00000vcj0k1iuocuu  cmf51ieam0001vcj0kljobiod  1BHK
#
#        price              status  \
# 0   11111111  UNDER_CONSTRUCTION
# 1   22222222  UNDER_CONSTRUCTION
# 2  120000000       READY_TO_MOVE
# 3  210000000       READY_TO_MOVE
# 4   13000000  UNDER_CONSTRUCTION
#
#                                               slug projectSummary  \
# 0  luxury-ashwini-ashoknagar-chembur-mumbai-675058        Unknown
# 1  luxury-ashwini-ashoknagar-chembur-mumbai-675058        Unknown
# 2  pristine02-modelcolony-shivajinagar-pune-428955        Unknown
# ...

# %%
df_clean.shape
# Out:
# (83, 10)

# %%
df_clean = df_clean.drop(['cityId'], axis = 1)
df_clean.head()
# Out:
#   projectName                 localityId  type      price              status  \
# 0     Ashwini  cmf6pksk30035vcxs7r2mo3iq  1BHK   11111111  UNDER_CONSTRUCTION
# 1     Ashwini  cmf6pksk30035vcxs7r2mo3iq  2BHK   22222222  UNDER_CONSTRUCTION
# 2  Pristine02  cmf6pk0cn0033vcxshxbf5hdh  2BHK  120000000       READY_TO_MOVE
# 3  Pristine02  cmf6pk0cn0033vcxshxbf5hdh  2BHK  210000000       READY_TO_MOVE
# 4   Gurukripa  cmf51ieam0001vcj0kljobiod  1BHK   13000000  UNDER_CONSTRUCTION
#
#                                               slug projectSummary  \
# 0  luxury-ashwini-ashoknagar-chembur-mumbai-675058        Unknown
# 1  luxury-ashwini-ashoknagar-chembur-mumbai-675058        Unknown
# 2  pristine02-modelcolony-shivajinagar-pune-428955        Unknown
# 3  pristine02-modelcolony-shivajinagar-pune-428955        Unknown
# 4       gurukripa-ashoknagar-chembur-mumbai-086047        Unknown
#
#                                       propertyImages  \
# ...

# %%
df_clean = df_clean.drop(['localityId'], axis = 1)
df_clean.head()
# Out:
#   projectName  type      price              status  \
# 0     Ashwini  1BHK   11111111  UNDER_CONSTRUCTION
# 1     Ashwini  2BHK   22222222  UNDER_CONSTRUCTION
# 2  Pristine02  2BHK  120000000       READY_TO_MOVE
# 3  Pristine02  2BHK  210000000       READY_TO_MOVE
# 4   Gurukripa  1BHK   13000000  UNDER_CONSTRUCTION
#
#                                               slug projectSummary  \
# 0  luxury-ashwini-ashoknagar-chembur-mumbai-675058        Unknown
# 1  luxury-ashwini-ashoknagar-chembur-mumbai-675058        Unknown
# 2  pristine02-modelcolony-shivajinagar-pune-428955        Unknown
# 3  pristine02-modelcolony-shivajinagar-pune-428955        Unknown
# 4       gurukripa-ashoknagar-chembur-mumbai-086047        Unknown
#
#                                       propertyImages  \
# 0  ["https://pub-d28896f69c604ec5aa743cb0397740d9...
# 1  ["https://pub-d28896f69c604ec5aa743cb0397740d9...
# 2  ["https://pub-d28896f69c604ec5aa743cb0397740d9...
# ...

# %%
df_clean = df_clean.rename(columns={
    "projectName": "Project Name",
    "type": "BHK",
    "status": "Possession Status (Ready / Under Construction)",
    "projectSummary": "amenities"
})

# %%
df_clean.head()
# Out:
#   Project Name   BHK      price  \
# 0      Ashwini  1BHK   11111111
# 1      Ashwini  2BHK   22222222
# 2   Pristine02  2BHK  120000000
# 3   Pristine02  2BHK  210000000
# 4    Gurukripa  1BHK   13000000
#
#   Possession Status (Ready / Under Construction)  \
# 0                             UNDER_CONSTRUCTION
# 1                             UNDER_CONSTRUCTION
# 2                                  READY_TO_MOVE
# 3                                  READY_TO_MOVE
# 4                             UNDER_CONSTRUCTION
#
#                                               slug amenities  \
# 0  luxury-ashwini-ashoknagar-chembur-mumbai-675058   Unknown
# 1  luxury-ashwini-ashoknagar-chembur-mumbai-675058   Unknown
# 2  pristine02-modelcolony-shivajinagar-pune-428955   Unknown
# 3  pristine02-modelcolony-shivajinagar-pune-428955   Unknown
# 4       gurukripa-ashoknagar-chembur-mumbai-086047   Unknown
#
#                                       propertyImages  \
# ...

# %%
df_clean["Title"] = df_clean["Project Name"].astype(str) + " " + df_clean["BHK"].astype(str)

# %%
df_clean.head()
# Out:
#   Project Name   BHK      price  \
# 0      Ashwini  1BHK   11111111
# 1      Ashwini  2BHK   22222222
# 2   Pristine02  2BHK  120000000
# 3   Pristine02  2BHK  210000000
# 4    Gurukripa  1BHK   13000000
#
#   Possession Status (Ready / Under Construction)  \
# 0                             UNDER_CONSTRUCTION
# 1                             UNDER_CONSTRUCTION
# 2                                  READY_TO_MOVE
# 3                                  READY_TO_MOVE
# 4                             UNDER_CONSTRUCTION
#
#                                               slug amenities  \
# 0  luxury-ashwini-ashoknagar-chembur-mumbai-675058   Unknown
# 1  luxury-ashwini-ashoknagar-chembur-mumbai-675058   Unknown
# 2  pristine02-modelcolony-shivajinagar-pune-428955   Unknown
# 3  pristine02-modelcolony-shivajinagar-pune-428955   Unknown
# 4       gurukripa-ashoknagar-chembur-mumbai-086047   Unknown
#
#                                       propertyImages  \
# ...

# %%
import pandas as pd
df_clean.to_csv('cleaned_file.csv', index=False)

# %%
df = pd.read_csv('cleaned_file.csv')
df.slug.head(10)
# Out:
# 0    luxury-ashwini-ashoknagar-chembur-mumbai-675058
# 1    luxury-ashwini-ashoknagar-chembur-mumbai-675058
# 2    pristine02-modelcolony-shivajinagar-pune-428955
# 3    pristine02-modelcolony-shivajinagar-pune-428955
# 4         gurukripa-ashoknagar-chembur-mumbai-086047
# 5         gurukripa-ashoknagar-chembur-mumbai-086047
# 6         gurukripa-ashoknagar-chembur-mumbai-086047
# 7         gurukripa-ashoknagar-chembur-mumbai-086047
# 8         gurukripa-ashoknagar-chembur-mumbai-086047
# 9         gurukripa-ashoknagar-chembur-mumbai-086047
# Name: slug, dtype: object

# %%
def extract_city_locality(slug):
    parts = slug.split("-")
    if len(parts) < 3:
        return "Unknown", "Unknown"
    
    city = parts[-2]  # second last word → city
    locality = " ".join(parts[2:-2]) if len(parts) > 4 else "Unknown"
    return city.capitalize(), locality.replace("-", " ").title()

# %%
df[["City", "Locality"]] = df["slug"].apply(
    lambda x: pd.Series(extract_city_locality(str(x)))
)

# %%
df["City + Locality"] = df["City"] + " - " + df["Locality"]

# %%
df.head()
# Out:
#   Project Name   BHK      price  \
# 0      Ashwini  1BHK   11111111
# 1      Ashwini  2BHK   22222222
# 2   Pristine02  2BHK  120000000
# 3   Pristine02  2BHK  210000000
# 4    Gurukripa  1BHK   13000000
#
#   Possession Status (Ready / Under Construction)  \
# 0                             UNDER_CONSTRUCTION
# 1                             UNDER_CONSTRUCTION
# 2                                  READY_TO_MOVE
# 3                                  READY_TO_MOVE
# 4                             UNDER_CONSTRUCTION
#
#                                               slug amenities  \
# 0  luxury-ashwini-ashoknagar-chembur-mumbai-675058   Unknown
# 1  luxury-ashwini-ashoknagar-chembur-mumbai-675058   Unknown
# 2  pristine02-modelcolony-shivajinagar-pune-428955   Unknown
# 3  pristine02-modelcolony-shivajinagar-pune-428955   Unknown
# 4       gurukripa-ashoknagar-chembur-mumbai-086047   Unknown
#
#                                       propertyImages  \
# ...

# %%
df = df.drop(['slug'], axis = 1)
df.head()
# Out:
#   Project Name   BHK      price  \
# 0      Ashwini  1BHK   11111111
# 1      Ashwini  2BHK   22222222
# 2   Pristine02  2BHK  120000000
# 3   Pristine02  2BHK  210000000
# 4    Gurukripa  1BHK   13000000
#
#   Possession Status (Ready / Under Construction) amenities  \
# 0                             UNDER_CONSTRUCTION   Unknown
# 1                             UNDER_CONSTRUCTION   Unknown
# 2                                  READY_TO_MOVE   Unknown
# 3                                  READY_TO_MOVE   Unknown
# 4                             UNDER_CONSTRUCTION   Unknown
#
#                                       propertyImages  \
# 0  ["https://pub-d28896f69c604ec5aa743cb0397740d9...
# 1  ["https://pub-d28896f69c604ec5aa743cb0397740d9...
# 2  ["https://pub-d28896f69c604ec5aa743cb0397740d9...
# 3  ["https://pub-d28896f69c604ec5aa743cb0397740d9...
# 4  ["https://pub-d28896f69c604ec5aa743cb0397740d9...
#
#                                          fullAddress            Title    City  \
# ...

# %%
df_new = df.copy()

# %%
df_new.dtypes
# Out:
# Project Name                                      object
# BHK                                               object
# price                                              int64
# Possession Status (Ready / Under Construction)    object
# amenities                                         object
# propertyImages                                    object
# fullAddress                                       object
# Title                                             object
# City                                              object
# Locality                                          object
# City + Locality                                   object
# dtype: object

# %%
import pandas as pd


# ✅ Step 1: Define the formatting function
def format_price(price):
    try:
        price = float(price)
    except:
        return "Unknown"
    
    if price >= 1e7:  # 1 crore = 10,000,000
        return f"₹{round(price / 1e7, 2)} Cr"
    elif price >= 1e5:  # 1 lakh = 100,000
        return f"₹{round(price / 1e5, 2)} L"
    else:
        return f"₹{int(price)}"

# ✅ Step 2: Apply formatting
df_new["price"] = df_new["price"].apply(format_price)



print("✅ Price column formatted and saved as 'Price (formatted as ₹X Cr / ₹X L)'")
# Out:
# ✅ Price column formatted and saved as 'Price (formatted as ₹X Cr / ₹X L)'

# %%
df_new.head()
# Out:
#   Project Name   BHK     price Possession Status (Ready / Under Construction)  \
# 0      Ashwini  1BHK  ₹1.11 Cr                             UNDER_CONSTRUCTION
# 1      Ashwini  2BHK  ₹2.22 Cr                             UNDER_CONSTRUCTION
# 2   Pristine02  2BHK  ₹12.0 Cr                                  READY_TO_MOVE
# 3   Pristine02  2BHK  ₹21.0 Cr                                  READY_TO_MOVE
# 4    Gurukripa  1BHK   ₹1.3 Cr                             UNDER_CONSTRUCTION
#
#   amenities                                     propertyImages  \
# 0   Unknown  ["https://pub-d28896f69c604ec5aa743cb0397740d9...
# 1   Unknown  ["https://pub-d28896f69c604ec5aa743cb0397740d9...
# 2   Unknown  ["https://pub-d28896f69c604ec5aa743cb0397740d9...
# 3   Unknown  ["https://pub-d28896f69c604ec5aa743cb0397740d9...
# 4   Unknown  ["https://pub-d28896f69c604ec5aa743cb0397740d9...
#
#                                          fullAddress            Title    City  \
# ...

# %%
df_new = df_new.drop(['Price (formatted as ₹X Cr / ₹X L)'], axis=1)

# %%
df_new.head()
# Out:
#   Project Name   BHK     price Possession Status (Ready / Under Construction)  \
# 0      Ashwini  1BHK  ₹1.11 Cr                             UNDER_CONSTRUCTION
# 1      Ashwini  2BHK  ₹2.22 Cr                             UNDER_CONSTRUCTION
# 2   Pristine02  2BHK  ₹12.0 Cr                                  READY_TO_MOVE
# 3   Pristine02  2BHK  ₹21.0 Cr                                  READY_TO_MOVE
# 4    Gurukripa  1BHK   ₹1.3 Cr                             UNDER_CONSTRUCTION
#
#   amenities                                     propertyImages  \
# 0   Unknown  ["https://pub-d28896f69c604ec5aa743cb0397740d9...
# 1   Unknown  ["https://pub-d28896f69c604ec5aa743cb0397740d9...
# 2   Unknown  ["https://pub-d28896f69c604ec5aa743cb0397740d9...
# 3   Unknown  ["https://pub-d28896f69c604ec5aa743cb0397740d9...
# 4   Unknown  ["https://pub-d28896f69c604ec5aa743cb0397740d9...
#
#                                          fullAddress            Title    City  \
# ...

# %%
import pandas as pd
import re


# ✅ Clean the propertyImages column
def clean_image_link(value):
    if pd.isna(value):
        return "Unknown"
    # Remove brackets and quotes using regex
    cleaned = re.sub(r'[\[\]\']""', '', str(value)).strip()
    return cleaned

df_new["propertyImages"] = df_new["propertyImages"].apply(clean_image_link)

# ✅ Save cleaned CSV
df_new.to_csv("cleaned_property_images.csv", index=False, encoding="utf-8-sig")

print("✅ propertyImages column cleaned — brackets removed and file saved as 'cleaned_property_images.csv'")
# Out:
# ✅ propertyImages column cleaned — brackets removed and file saved as 'cleaned_property_images.csv'

# %%
df_new.head()
# Out:
#   Project Name   BHK     price Possession Status (Ready / Under Construction)  \
# 0      Ashwini  1BHK  ₹1.11 Cr                             UNDER_CONSTRUCTION
# 1      Ashwini  2BHK  ₹2.22 Cr                             UNDER_CONSTRUCTION
# 2   Pristine02  2BHK  ₹12.0 Cr                                  READY_TO_MOVE
# 3   Pristine02  2BHK  ₹21.0 Cr                                  READY_TO_MOVE
# 4    Gurukripa  1BHK   ₹1.3 Cr                             UNDER_CONSTRUCTION
#
#   amenities                                     propertyImages  \
# 0   Unknown  "https://pub-d28896f69c604ec5aa743cb0397740d9....
# 1   Unknown  "https://pub-d28896f69c604ec5aa743cb0397740d9....
# 2   Unknown  "https://pub-d28896f69c604ec5aa743cb0397740d9....
# 3   Unknown  "https://pub-d28896f69c604ec5aa743cb0397740d9....
# 4   Unknown  "https://pub-d28896f69c604ec5aa743cb0397740d9....
#
#                                          fullAddress            Title    City  \
# ...
